# %% [markdown]
# # Supermarket analysis
#
# In this file, I'll check if a supermarket sales dataset is clean and contains relevant data. Next, I'll be creating some charts

# %%
# Importing data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import datetime as dt

dados = pd.read_csv('C:\\Users\\Sergio\\Desktop\\Danilo\\Estudos\\Python\\supermarket_sales - Sheet1.csv')
dados = pd.DataFrame(dados)
dados.head(50)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
# Checking data (select distinct)

print('City\n', dados['City'].unique(), '\n')
print('Product line\n', dados['Product line'].unique(), '\n')
print('MaxUnit price\n', dados['Unit price'].max(), '\n')
print('MinUnit price\n', dados['Unit price'].min(), '\n')
print('Payment\n', dados['Payment'].unique(), '\n')
# Out:
# City
#  ['Yangon' 'Naypyitaw' 'Mandalay']
#
# Product line
#  ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
#
# MaxUnit price
#  99.96
#
# MinUnit price
#  10.08
#
# Payment
#  ['Ewallet' 'Cash' 'Credit card']

# %%
# Main statistics

dados.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
# Grouping data by gender and formatting to 2 decimal places

dados.groupby(['Gender']).agg({'Unit price': ['min', 'mean', 'max'], 'Total': ['min', 'mean', 'max']}).style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_78db5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78db5_level0_col0" class="col_heading level0 col0" colspan="3">Unit price</th>
#       <th id="T_78db5_level0_col3" class="col_heading level0 col3" colspan="3">Total</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_78db5_level1_col0" class="col_heading level1 col0" >min</th>
#       <th id="T_78db5_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_78db5_level1_col2" class="col_heading level1 col2" >max</th>
#       <th id="T_78db5_level1_col3" class="col_heading level1 col3" >min</th>
#       <th id="T_78db5_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_78db5_level1_col5" class="col_heading level1 col5" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# Other groups

tabela = dados.groupby('City').agg({'Invoice ID': ['count'], 'Total': ['mean']})

tabela.style.format({('Total', 'mean'): "{:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcfe1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcfe1_level0_col0" class="col_heading level0 col0" >Invoice ID</th>
#       <th id="T_fcfe1_level0_col1" class="col_heading level0 col1" >Total</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_fcfe1_level1_col0" class="col_heading level1 col0" >count</th>
#       <th id="T_fcfe1_level1_col1" class="col_heading level1 col1" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcfe1_level0_row0" class="row_heading level0 row0" >Mandalay</th>
#       <td id="T_fcfe1_row0_col0" class="data row0 col0" >332</td>
#       <td id="T_fcfe1_row0_col1" class="data row0 col1" >319.87</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Charts

# %% [markdown]
# **Pie chart that shows the percentage that each product line represents in total sales**

# %%
# Group by product line
productline = dados.groupby('Product line').sum()[['Total']]

# Calculating percentages
productline['percentage'] = productline['Total'] / productline['Total'].sum() * 100

# Creating chart
plt.pie(
    productline['percentage'], # values
    labels = productline.index, # names
    autopct = '%1.1f%%', # format to 1 decimal place
    wedgeprops = {'linewidth': 3, 'edgecolor' : 'white'}) # Details

plt.show()
# Out:
# C:\Users\Sergio\AppData\Local\Temp\ipykernel_24068\107927429.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   productline = dados.groupby('Product line').sum()[['Total']]

# %% [markdown]
# **Bar chart grouped by city that shows the average total sales for each month**

# %%
dados['Date'] = pd.to_datetime(dados['Date']) # converting 'Date' column from string to date
dados['month'] = dados['Date'].dt.strftime('%Y-%m') # creating 'Month' column from 'Date'

# Pivot table that groups data by city and month
dados_pormês = dados.pivot_table(index='month', columns='City', values='Total', aggfunc='sum', fill_value=0) 

# Printing data that should be exhibited on the chart
dados_pormês = (dados_pormês/1000) # divide os valores por 1000
dados_pormês = pd.DataFrame(dados_pormês)
print(dados_pormês)

# Creating list of values for each city
mandalay = dados_pormês.iloc[0].tolist()
naypyitaw = dados_pormês.iloc[1].tolist()
yangon = dados_pormês.iloc[2].tolist()

# Creating list of months
meses = dados_pormês.columns.tolist()

plot_dados = pd.DataFrame(dados_pormês, index = meses)

# Creating chart
ax = dados_pormês.plot(kind = 'bar')
for p in ax.patches: # Add label for each bar
    ax.annotate(f"{p.get_height():.2f}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 5), 
                textcoords='offset points', 
                fontsize = 8)
plt.ylabel('Total')
plt.ylim(0, 55)
# Out:
# City      Mandalay  Naypyitaw     Yangon
# month
# 2019-01  37.176058  40.434681  38.681128
# 2019-02  34.424271  32.934982  29.860121
# 2019-03  34.597342  37.199043  37.659121
# (0.0, 55.0)
